# %% [markdown]
# # Bar Plot with Matplotlib in Python

# %% [markdown]
# Hi Guys, Welcome to [Tirendaz Academy](https://youtube.com/c/tirendazacademy) 😀
# </br>
# In this notebook, I'm going to talk about bar plot with Matplotlib.
# </br>
# Happy learning 🐱‍🏍

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
plt.style.use("fivethirtyeight")

# %%
Math=np.random.randint(50,100,7)
Stat=np.random.randint(50,100,7)
CS=np.random.randint(50,100,7)

# %%
classes=list("ABCDEFG")

# %%
plt.plot(classes, Math, label="Math Avg")
plt.plot(classes, Stat, label="Stat Avg")
plt.plot(classes, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(0, 0.5, 'Averages')

# %%
plt.bar(classes, Math, label="Math Avg")
plt.bar(classes, Stat, label="Stat Avg")
plt.bar(classes, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(0, 0.5, 'Averages')

# %%
x_indeks=np.arange(len(classes))

# %%
x=0.25
plt.bar(x_indeks-x, Math, label="Math Avg")
plt.bar(x_indeks, Stat, label="Stat Avg")
plt.bar(x_indeks+x, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(0, 0.5, 'Averages')

# %%
plt.bar(x_indeks-x,Math,width=x,label="Math Avg")
plt.bar(x_indeks,Stat,width=x,label="Stat Avg")
plt.bar(x_indeks+x, CS, width=x, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(0, 0.5, 'Averages')

# %%
plt.bar(x_indeks-x,Math,width=x,label="Math Avg")
plt.bar(x_indeks, Stat, width=x,label="Stat Avg")
plt.bar(x_indeks+x, CS, width=x, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
plt.xticks(ticks=x_indeks, labels=classes)
# Out:
# ([<matplotlib.axis.XTick at 0x15728b5afa0>,
#   <matplotlib.axis.XTick at 0x15728b5af70>,
#   <matplotlib.axis.XTick at 0x157289c7ee0>,
#   <matplotlib.axis.XTick at 0x15728bc5280>,
#   <matplotlib.axis.XTick at 0x15728bc56a0>,
#   <matplotlib.axis.XTick at 0x15728bc5af0>,
#   <matplotlib.axis.XTick at 0x15728bcb040>],
#  [Text(0, 0, 'A'),
#   Text(1, 0, 'B'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'D'),
#   Text(4, 0, 'E'),
#   Text(5, 0, 'F'),
#   Text(6, 0, 'G')])

# %% [markdown]
# ## Error Bar

# %%
x=np.linspace(0,10,30)

# %%
y=np.random.randint(0,5,30)

# %%
plt.plot(x,y,"bo")

# %%
plt.plot(x,y,"bo")
plt.errorbar(x,y,yerr=1, fmt=".k")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.plot(x,y,"bo")
plt.errorbar(x,y,xerr=1, fmt=".k")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x, y, 
             yerr=1, 
             fmt='bo', 
             ecolor='red', 
             elinewidth=2, 
             capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Bar Graph with Error Bars

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
mean = np.mean(iris.data, axis=0)
sd = np.std(iris.data, axis=0)

# %%
interval = range(4)

# %%
plt.barh(interval ,mean, color="b", 
         xerr=sd, alpha=0.7, align="center")
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(interval ,mean, color="b", 
         xerr=sd, alpha=0.7, align="center")
plt.title('Horizontal Bars')
# Out:
# Text(0.5, 1.0, 'Horizontal Bars')

# %%
plt.barh(interval ,mean, color="b", xerr=sd, 
         alpha=0.7, align="center")
plt.title('Horizontal Bars')
plt.yticks(interval, iris.feature_names)
# Out:
# ([<matplotlib.axis.YTick at 0x1572b0f31f0>,
#   <matplotlib.axis.YTick at 0x1572b0f0dc0>,
#   <matplotlib.axis.YTick at 0x1572b0eac10>,
#   <matplotlib.axis.YTick at 0x1572b128160>],
#  [Text(0, 0, 'sepal length (cm)'),
#   Text(0, 1, 'sepal width (cm)'),
#   Text(0, 2, 'petal length (cm)'),
#   Text(0, 3, 'petal width (cm)')])

# %%
plt.bar(interval, mean, color="m", 
        yerr=sd, alpha=0.7, align="center")
plt.title('Vertical Bars')
# Out:
# Text(0.5, 1.0, 'Vertical Bars')

# %%
plt.bar(interval, mean, color="m", yerr=sd, 
        alpha=0.7, align="center")
plt.title('Vertical Bars')
plt.xticks(interval, 
           iris.feature_names, 
           rotation=70)
# Out:
# ([<matplotlib.axis.XTick at 0x15728c899d0>,
#   <matplotlib.axis.XTick at 0x1572b1b37f0>,
#   <matplotlib.axis.XTick at 0x1572b1b0550>,
#   <matplotlib.axis.XTick at 0x1572b1ed040>],
#  [Text(0, 0, 'sepal length (cm)'),
#   Text(1, 0, 'sepal width (cm)'),
#   Text(2, 0, 'petal length (cm)'),
#   Text(3, 0, 'petal width (cm)')])

# %%
plt.bar(interval, mean, color="m", yerr=sd, 
        alpha=0.7, width=0.5, align="center")
plt.title('Vertical Bars')
plt.xticks(interval, 
           iris.feature_names, 
           rotation=70)
# Out:
# ([<matplotlib.axis.XTick at 0x1572b212520>,
#   <matplotlib.axis.XTick at 0x1572b2124f0>,
#   <matplotlib.axis.XTick at 0x1572b210040>,
#   <matplotlib.axis.XTick at 0x1572b240cd0>],
#  [Text(0, 0, 'sepal length (cm)'),
#   Text(1, 0, 'sepal width (cm)'),
#   Text(2, 0, 'petal length (cm)'),
#   Text(3, 0, 'petal width (cm)')])

# %% [markdown]
# Don't forget to follow us on [YouTube](http://youtube.com/tirendazacademy) | [Medium](http://tirendazacademy.medium.com) | [Twitter](http://twitter.com/tirendazacademy) | [GitHub](http://github.com/tirendazacademy) | [Linkedin](https://www.linkedin.com/in/tirendaz-academy) | [Kaggle](https://www.kaggle.com/tirendazacademy) 😎
